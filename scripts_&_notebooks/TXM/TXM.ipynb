# %%
# %matplotlib inline

# %%
from TXM import *

# %% [markdown]
# # Nuages de points -cooccurrences

# %%
cooc('/home/adrien-escoda/Documents/TXM/exports/coocurrences_guerre.csv')

# %%
cooc('/home/adrien-escoda/Documents/TXM/exports/coocurrences_Allemagne.csv')

# %%
cooc('/home/adrien-escoda/Documents/TXM/exports/coocurrences_Boulanger_contexte01_NET_PT.csv')

# %%
cooc('/home/adrien-escoda/Documents/TXM/exports/coocurrences_Boulanger_contexte10_NET_PT.csv')
plt.savefig('boulanger.jpg')

# %%
cooc('/home/adrien-escoda/Documents/TXM/exports/coocurrences_coup_Etat.csv')

# %%
cooc('/home/adrien-escoda/Documents/TXM/exports/coocurrences_dictat.csv')

# %%
cooc('/home/adrien-escoda/Documents/TXM/exports/coocurrences_guerre.csv')

# %%
cooc('/home/adrien-escoda/Documents/TXM/exports/coocurrences_populaire.csv')

# %%
cooc('/home/adrien-escoda/Documents/TXM/exports/coocurrences_revanche.csv')

# %%
cooc('/home/adrien-escoda/Documents/TXM/exports/coocurrences_Ferron_contexte10.csv')

# %%
cooc('/home/adrien-escoda/Documents/TXM/exports/coocurrences_vive.csv')

# %% [markdown]
# # Nuages de lemmes

# %%
nuage('/home/adrien-escoda/Documents/TXM/exports/mots_frequents_freq3000+.csv')
plt.savefig('saved.jpeg')

# %% [markdown]
# # Nombre de fichiers à n occurrences du token choisi par fichier

# %%
#fréquence du NAM 'Boulanger'
histo_boulanger('/home/adrien-escoda/Documents/TXM/exports/boulanger_par_date_NET_PT.csv')

# %%
#histogramme du NAM 'Bismarck'
histo_bismarck('/home/adrien-escoda/Documents/TXM/exports/bismarck_par_date.csv')

# %%
#histogramme du NAM 'Clémenceau'
histo_clemenceau('/home/adrien-escoda/Documents/TXM/exports/clemenceau_par_date.csv')

# %%
#histogramme du NAM 'Grévy'
histo_grevy('/home/adrien-escoda/Documents/TXM/exports/grevy_par_date.csv')

# %%
#histogramme du NAM 'Goblet'
histo_goblet('/home/adrien-escoda/Documents/TXM/exports/goblet_par_date.csv')
